# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrainHernandezCortes/EDP1/blob/main/Ondas_viajeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Se añaden las librerías necesarias.

# %%
c = 1.0
t = 0.2
x = np.linspace(0, 1, 100)

# %% [markdown]
# Se agregan los parámetros.

# %%
def f(xp):
    return np.exp(-((xp - 0.5)**2) / 0.01)
p_derecha = f(x - c * t)
p_izquierda = f(x + c * t)
p_superpuesta = p_derecha + p_izquierda

# %% [markdown]
# Se define la función f(x´), así como la perturbación que se desplaza a la derecha, la que se desplaza a la izquierda y la superposición de las ondas viajeras.

# %%
plt.figure(figsize=(10, 5))
plt.plot(x, p_derecha, color='lightblue')
plt.title("Inciso (a): (x' = x - ct)")
plt.xlabel("x")
plt.ylabel("f(x, t)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se grafica el inciso (a).

# %%
plt.figure(figsize=(10, 5))
plt.plot(x, p_izquierda, color='purple')
plt.title("Inciso (b): (x' = x + ct)")
plt.xlabel("x")
plt.ylabel("f(x, t)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se grafica el inciso (b).

# %%
plt.figure(figsize=(10, 5))
plt.plot(x, p_superpuesta, color='orange')
plt.title("Inciso (c)")
plt.xlabel("x")
plt.ylabel("f(x, t)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se grafica el inciso (c).
