# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrainHernandezCortes/EDP1/blob/main/Fourier%20en%20senos%20y%20en%20cosenos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import fourier_series, pi, plot, Piecewise, exp
from sympy.abc import x
import matplotlib.pyplot as plt

# %% [markdown]
# Se importan las librerías necesarias.

# %%
f1=Piecewise(
    (exp(2*x), (x >= 0) & (x < 1)),
    (-exp(-2*x),(x > -1) & (x < 0)))
f2=Piecewise(
    (exp(2*x), (x >= 0) & (x <= 1)),
    (exp(-2*x), (x > -1) & (x < 1))
)
f3=Piecewise(
    (1, (x >= 0) & (x <= pi/2)),
    (2, (x > pi/2) & (x<=pi)))

# %% [markdown]
# Se definen las funciones en el intervalo dado.

# %%
plot(f1, (x,-1,1),line_color ='blue')
plot(f2, (x,-1,1), line_color='red')
plot(f3, (x,0,pi),line_color ='green')

# %% [markdown]
# Se grafican las funciones.
# En color azul la impar, en color rojo la par y la función a trozos en color verde.

# %%
s = fourier_series(f1, (x, 0, 1))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, 0, 1), show=False, legend=True)

t = fourier_series(f2, (x, 0, 1))
r1 = s.truncate(n = 3)
r2 = s.truncate(n = 5)
r3 = s.truncate(n = 7)
q = plot(f2, r1, r2, r3, (x, 0, 1), show=False, legend=True)

d = fourier_series(f3, (x, 0, pi))
d1 = s.truncate(n = 3)
d2 = s.truncate(n = 5)
d3 = s.truncate(n = 7)
k = plot(f3, d1, d2, d3, (x, 0, pi), show=False, legend=True)

# %% [markdown]
# Se calculan las series de Fourier.

# %%
s
# Out:
# FourierSeries(Piecewise((exp(2*x), (x >= 0) & (x < 1)), (-exp(-2*x), (x > -1) & (x < 0))), (x, 0, 1), (-1/2 + exp(2)/2, SeqFormula(2*(_n*pi*exp(2)*sin(2*_n*pi)/(2*_n**2*pi**2 + 2) + exp(2)*cos(2*_n*pi)/(2*_n**2*pi**2 + 2) - 1/(2*_n**2*pi**2 + 2))*cos(2*_n*pi*x), (_n, 1, oo)), SeqFormula(2*(-_n*pi*exp(2)*cos(2*_n*pi)/(2*_n**2*pi**2 + 2) + _n*pi/(2*_n**2*pi**2 + 2) + exp(2)*sin(2*_n*pi)/(2*_n**2*pi**2 + 2))*sin(2*_n*pi*x), (_n, 1, oo))))

# %%
t
# Out:
# FourierSeries(Piecewise((exp(2*x), (x >= 0) & (x <= 1)), (exp(-2*x), (x > -1) & (x < 1))), (x, 0, 1), (-1/2 + exp(2)/2, SeqFormula(2*(_n*pi*exp(2)*sin(2*_n*pi)/(2*_n**2*pi**2 + 2) + exp(2)*cos(2*_n*pi)/(2*_n**2*pi**2 + 2) - 1/(2*_n**2*pi**2 + 2))*cos(2*_n*pi*x), (_n, 1, oo)), SeqFormula(2*(-_n*pi*exp(2)*cos(2*_n*pi)/(2*_n**2*pi**2 + 2) + _n*pi/(2*_n**2*pi**2 + 2) + exp(2)*sin(2*_n*pi)/(2*_n**2*pi**2 + 2))*sin(2*_n*pi*x), (_n, 1, oo))))

# %%
d
# Out:
# FourierSeries(Piecewise((1, (x >= 0) & (x <= pi/2)), (2, (x <= pi) & (x > pi/2))), (x, 0, pi), (3/2, SeqFormula(2*Piecewise((-sin(_n*pi)/(2*_n) + sin(2*_n*pi)/_n, (_n > -oo) & (_n < oo) & Ne(_n, 0)), (3*pi/2, True))*cos(2*_n*x)/pi, (_n, 1, oo)), SeqFormula(2*Piecewise((cos(_n*pi)/(2*_n) - cos(2*_n*pi)/_n + 1/(2*_n), (_n > -oo) & (_n < oo) & Ne(_n, 0)), (0, True))*sin(2*_n*x)/pi, (_n, 1, oo))))

# %% [markdown]
# Se muestran las series de Fourier.

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

q[0].label = 'x'
q[1].label = 'n=3'
q[2].label = 'n=5'
q[3].label = 'n=7'

k[0].label = 'x'
k[1].label = 'n=3'
k[2].label = 'n=5'
k[3].label = 'n=7'

# %%
p.show()
q.show()
k.show()

# %% [markdown]
# Se presentan las gráficas de las series de Fourier.
